# %%
import csv
import pandas as pd

# %%
data = pd.read_csv('FUEL_DIC.csv', header = 'infer')
data
# Out:
#     VALUE  Fuelfuelload   SAV  Packingratio  moisture
# 0      91          0.00     0      0.000000         0
# 1      92          0.00     0      0.000000         0
# 2      93          0.00     0      0.000000         0
# 3      98          0.00     0      0.000000         0
# 4      99          0.00     0      0.000000         0
# 5     101          0.40  2054      0.001430        15
# 6     102          1.10  1820      0.001580        15
# 7     103          1.60  1290      0.001430        30
# 8     104          2.15  1826      0.001540        15
# 9     105          2.90  1631      0.002770        40
# 10    106          3.50  2006      0.003350        40
# 11    107          6.40  1834      0.003060        15
# 12    108          7.80  1302      0.003160        30
# 13    109         10.00  1612      0.003160        40
# 14    121          1.35  1832      0.002150        15
# 15    122          2.10  1827      0.002490        15
# 16    123          3.00  1614      0.002590        40
# 17    124         12.40  1674      0.008740        40
# 18    141          1.70  1674      0.002800        15
# 19    142          5.20  1672      0.001198        15
# 20    143          6.65  1371      0.005770        40
# 21    144          3.40  1682      0.002270        30
# 22    145          6.50  1252      0.002060        15
# 23    146          4.30  1144      0.004120        30
# 24    147          6.90  1233      0.003440        15
# 25    148          6.40  1386      0.005090        40
# 26    149         13.05  1378      0.005050        40
# 27    161          1.30  1606      0.008850        20
# 28    162          1.15  1767      0.006030        30
# 29    163          2.85  1611      0.003590        30
# 30    164          6.50  2216      0.018650        12
# 31    165          7.00  1224      0.020090        25
# 32    181          1.00  1716      0.048780        30
# 33    182          1.40  1806      0.042320        25
# 34    183          0.50  1532      0.026300        20
# 35    184          0.50  1568      0.022240        25
# 36    185          1.15  1713      0.019250        25
# 37    186          2.40  1936      0.022960        25
# 38    187          0.30  1229      0.035150        25
# 39    188          5.80  1770      0.039690        35
# 40    189          6.65  1733      0.033720        35
# 41    201          1.50  1653      0.022240        25
# 42    202          4.50  1884      0.018290        25
# 43    203          5.50  1935      0.013450        25
# 44    204          5.25  1907      0.007440        25
# 45  -9999          0.00     0      0.000000         0

# %%
set1 = {203,92, 201, 189}
for i in set1:
    print(data.loc[data['VALUE'] == i])
# Out:
#     VALUE  Fuelfuelload   SAV  Packingratio  moisture
# 41    201           1.5  1653       0.02224        25
#     VALUE  Fuelfuelload   SAV  Packingratio  moisture
# 43    203           5.5  1935       0.01345        25
#    VALUE  Fuelfuelload  SAV  Packingratio  moisture
# 1     92           0.0    0           0.0         0
#     VALUE  Fuelfuelload   SAV  Packingratio  moisture
# 40    189          6.65  1733       0.03372        35

# %%
#check the numbers
import seaborn as sns
from operator import itemgetter
stats = {}

for i in data['VALUE']:
    
    if i is None:
        continue
    elif i in stats:
        stats[i] += 1
    else:
        stats[i] = 1
sorted_dict = dict( sorted(stats.items(),key=itemgetter(1),reverse=True))  
keys = sorted_dict.keys()

v = sorted_dict.values()

df = pd.DataFrame({'x':keys, 'y':v})
df.plot.bar(x='x', y='y')
# Out:
# <AxesSubplot:xlabel='x'>
